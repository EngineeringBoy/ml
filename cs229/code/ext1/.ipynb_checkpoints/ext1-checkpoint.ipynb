# %%
import pandas as pd
import numpy as np

datasets = pd.read_csv('ex1data1.txt', header=None, names=['Population', 'Profits'])
print(datasets)
# Out:
#     Population   Profits
# 0       6.1101  17.59200
# 1       5.5277   9.13020
# 2       8.5186  13.66200
# 3       7.0032  11.85400
# 4       5.8598   6.82330
# ..         ...       ...
# 92      5.8707   7.20290
# 93      5.3054   1.98690
# 94      8.2934   0.14454
# 95     13.3940   9.05510
# 96      5.4369   0.61705
#
# [97 rows x 2 columns]

# %%
from matplotlib import pyplot as plt
datasets.plot(kind='scatter',x='Population',y='Profits',figsize=(12,8))
plt.show()

# %%
print(datasets.head())
# Out:
#    Population  Profits
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
print(datasets.describe())
# Out:
#        Population    Profits
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000

# %%
datasets = datasets.insert(0,'Ones',1)
print(datasets.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-7e6c63adc21f> in <module>
# ----> 1 datasets = datasets.insert(0,'Ones',1)
#       2 print(datasets.head())
#
# AttributeError: 'NoneType' object has no attribute 'insert'

# %%
def cost(theta, x, y):
    J = x.dot(theta.T) - y
    return J
